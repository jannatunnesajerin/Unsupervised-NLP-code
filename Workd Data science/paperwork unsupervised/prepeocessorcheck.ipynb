# %%
import nltk
 
try:
    print("Testing NLTK components...")
    
    # 1. Test 'punkt' by splitting a sentence into words
    words = nltk.word_tokenize("Hello world, NLTK is working.")
    print("✅ 'punkt' is OK!")
    
    # 2. Test 'stopwords' by loading the English list
    stops = nltk.corpus.stopwords.words('english')
    print("✅ 'stopwords' is OK!")
    
    # 3. Test 'wordnet' by lemmatizing a word
    from nltk.stem import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma = lemmatizer.lemmatize("running", pos="v")
    print("✅ 'wordnet' is OK!")
    
    print("\n🎉 Everything you need is 100% OK and ready for Machine Learning!")
 
except Exception as e:
    print(f"\n❌ Test failed on something. Error details: {e}")
# Out:
# Testing NLTK components...
# ✅ 'punkt' is OK!
# ✅ 'stopwords' is OK!
# ✅ 'wordnet' is OK!
#
# 🎉 Everything you need is 100% OK and ready for Machine Learning!

# %%
from nltk.stem import WordNetLemmatizerr
 
lemmatizerrrr = WordNetLemmatizer()
 
try:
    # Test a regular noun and verb
    noun_test = lemmatizer.lemmatize("datasets")
    verb_test = lemmatizer.lemmatize("running", pos="v")
    
    print("✅ Lemmatizer Check: Success!")
    print(f"Resulting words -> 'datasets' becomes: '{noun_test}', 'running' becomes: '{verb_test}'")
    print("Everything works perfectly for English data without omw-1.4.")
 
except ValueError as e:
    if "omw-1.4" in str(e):
        print("⚠️ Code explicitly requested omw-1.4.")
    else:
        print(f"❌ Other error: {e}")
# Out:
# ✅ Lemmatizer Check: Success!
# Resulting words -> 'datasets' becomes: 'datasets', 'running' becomes: 'run'
# Everything works perfectly for English data without omw-1.4.
